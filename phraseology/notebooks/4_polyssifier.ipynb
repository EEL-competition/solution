# %% [markdown]
# # Requirements

# %%
import sys
sys.path.append("../../") # go to grandparent dir

import numpy as np
from phraseology.model.dataset import load_dataset

# %% [markdown]
# # Classification problem

# %%
from polyssifier import poly
# Load data
data, labels = load_dataset("all", "classification")
# Run analysis
report = poly(data, labels, n_folds=5)
# Plot results
report.plot_scores()
report.plot_features(ntop=10)
# Out:
# 2022-12-04 15:04:11,224 - polyssifier - INFO - Detected 9 classes in label
# 2022-12-04 15:04:11,225 - polyssifier - INFO - Building classifiers ...
# 2022-12-04 15:04:11,250 - polyssifier - INFO - Initialization, done.
# 2022-12-04 15:04:18,059 - polyssifier - INFO - Training Multilayer Perceptron 0
# 2022-12-04 15:04:58,396 - polyssifier - INFO - Multilayer Perceptron      0: Train 0.99/Test 0.24, 40.34 sec
# 2022-12-04 15:05:03,537 - polyssifier - INFO - Training Multilayer Perceptron 1
# 2022-12-04 15:05:45,787 - polyssifier - INFO - Multilayer Perceptron      1: Train 0.99/Test 0.24, 42.25 sec
# 2022-12-04 15:05:50,779 - polyssifier - INFO - Training Multilayer Perceptron 2
# 2022-12-04 15:06:33,868 - polyssifier - INFO - Multilayer Perceptron      2: Train 0.99/Test 0.28, 43.09 sec
# 2022-12-04 15:06:38,859 - polyssifier - INFO - Training Multilayer Perceptron 3
# 2022-12-04 15:07:28,044 - polyssifier - INFO - Multilayer Perceptron      3: Train 0.99/Test 0.23, 49.18 sec
# ...

# %%
report.plot_scores()

# %% [markdown]
# # Regression problem

# %%
from polyssifier import polyr
# Load data
data, labels = load_dataset("all", "regression")
# Run analysis
report1 = polyr(data, labels, n_folds=5)
# Plot results
report1.plot_scores()
report1.plot_features(ntop=10)
# Out:
# 2022-11-27 21:49:31,034 - polyssifier - INFO - Building classifiers ...
# 2022-11-27 21:49:31,044 - polyssifier - INFO - Initialization, done.
# 2022-11-27 21:49:42,561 - polyssifier - INFO - Training Linear Regression 0
# 2022-11-27 21:49:53,701 - polyssifier - INFO - Linear Regression          0: Train 0.29/Test -8447880263380475477787410432.00, 11.14 sec
# 2022-11-27 21:50:02,071 - polyssifier - INFO - Training Linear Regression 1
# 2022-11-27 21:50:08,154 - polyssifier - INFO - Linear Regression          1: Train 0.42/Test -4998121540169147972937842688.00, 6.08 sec
# 2022-11-27 21:50:16,510 - polyssifier - INFO - Training Linear Regression 2
# 2022-11-27 21:50:22,438 - polyssifier - INFO - Linear Regression          2: Train 0.42/Test -888303409524059267655532544.00, 5.93 sec
# 2022-11-27 21:50:30,184 - polyssifier - INFO - Training Linear Regression 3
# ...
