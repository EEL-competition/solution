# %% [markdown]
# # Requirements

# %%
import sys
sys.path.append("../../") # go to grandparent dir

import numpy as np
from phraseology.model.dataset import load_dataset

# %% [markdown]
# # Classification problem

# %%
from polyssifier import poly
# Load data
data, labels = load_dataset("all", "classification")
# Run analysis
report = poly(data, labels, n_folds=5)
# Plot results
report.plot_scores()
report.plot_features(ntop=10)
# Out:
# 2022-11-27 19:09:59,169 - polyssifier - INFO - Detected 9 classes in label
# 2022-11-27 19:09:59,172 - polyssifier - INFO - Building classifiers ...
# 2022-11-27 19:09:59,193 - polyssifier - INFO - Initialization, done.
# 2022-11-27 19:10:11,795 - polyssifier - INFO - Training Multilayer Perceptron 0
# 2022-11-27 19:11:22,169 - polyssifier - INFO - Multilayer Perceptron      0: Train 0.99/Test 0.22, 70.37 sec
# 2022-11-27 19:11:30,366 - polyssifier - INFO - Training Multilayer Perceptron 1
# 2022-11-27 19:12:46,532 - polyssifier - INFO - Multilayer Perceptron      1: Train 0.99/Test 0.27, 76.17 sec
# 2022-11-27 19:12:56,363 - polyssifier - INFO - Training Multilayer Perceptron 2
# 2022-11-27 19:14:10,819 - polyssifier - INFO - Multilayer Perceptron      2: Train 0.99/Test 0.25, 74.46 sec
# 2022-11-27 19:14:26,498 - polyssifier - INFO - Training Multilayer Perceptron 3
# 2022-11-27 19:15:50,929 - polyssifier - INFO - Multilayer Perceptron      3: Train 0.99/Test 0.24, 84.43 sec
# 2022-11-27 19:15:59,630 - polyssifier - INFO - Training Multilayer Perceptron 4
# 2022-11-27 19:17:05,230 - polyssifier - INFO - Multilayer Perceptron      4: Train 0.99/Test 0.23, 65.60 sec
# 2022-11-27 19:17:14,831 - polyssifier - INFO - Training Nearest Neighbors 0
# 2022-11-27 19:17:21,453 - polyssifier - INFO - Nearest Neighbors          0: Train 0.99/Test 0.21, 6.62 sec
# 2022-11-27 19:17:29,780 - polyssifier - INFO - Training Nearest Neighbors 1
# 2022-11-27 19:17:37,197 - polyssifier - INFO - Nearest Neighbors          1: Train 0.99/Test 0.23, 7.42 sec
# 2022-11-27 19:17:45,134 - polyssifier - INFO - Training Nearest Neighbors 2
# 2022-11-27 19:17:53,066 - polyssifier - INFO - Nearest Neighbors          2: Train 0.99/Test 0.24, 7.93 sec
# 2022-11-27 19:18:01,459 - polyssifier - INFO - Training Nearest Neighbors 3
# 2022-11-27 19:18:09,130 - polyssifier - INFO - Nearest Neighbors          3: Train 0.99/Test 0.24, 7.67 sec
# 2022-11-27 19:18:17,791 - polyssifier - INFO - Training Nearest Neighbors 4
# 2022-11-27 19:18:25,475 - polyssifier - INFO - Nearest Neighbors          4: Train 0.99/Test 0.20, 7.68 sec
# 2022-11-27 19:18:34,590 - polyssifier - INFO - Training SVM 0
# 2022-11-27 19:27:38,962 - polyssifier - INFO - SVM                        0: Train 0.49/Test 0.11, 544.37 sec
# 2022-11-27 19:27:45,772 - polyssifier - INFO - Training SVM 1
# 2022-11-27 19:38:17,634 - polyssifier - INFO - SVM                        1: Train 0.47/Test 0.16, 631.86 sec
# 2022-11-27 19:38:28,347 - polyssifier - INFO - Training SVM 2
# 2022-11-27 19:48:55,216 - polyssifier - INFO - SVM                        2: Train 0.43/Test 0.14, 626.87 sec
# 2022-11-27 19:49:05,447 - polyssifier - INFO - Training SVM 3
# 2022-11-27 20:01:20,624 - polyssifier - INFO - SVM                        3: Train 0.46/Test 0.14, 735.18 sec
# 2022-11-27 20:01:28,491 - polyssifier - INFO - Training SVM 4
# 2022-11-27 20:10:31,956 - polyssifier - INFO - SVM                        4: Train 0.44/Test 0.15, 543.47 sec
# 2022-11-27 20:10:39,581 - polyssifier - INFO - Training Linear SVM 0
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# 2022-11-27 20:25:59,837 - polyssifier - INFO - Linear SVM                 0: Train 0.69/Test 0.22, 920.26 sec
# 2022-11-27 20:26:06,301 - polyssifier - INFO - Training Linear SVM 1
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# 2022-11-27 20:40:13,944 - polyssifier - INFO - Linear SVM                 1: Train 0.65/Test 0.24, 847.64 sec
# 2022-11-27 20:40:20,205 - polyssifier - INFO - Training Linear SVM 2
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# 2022-11-27 20:58:13,744 - polyssifier - INFO - Linear SVM                 2: Train 0.68/Test 0.26, 1073.54 sec
# 2022-11-27 20:58:20,826 - polyssifier - INFO - Training Linear SVM 3
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# 2022-11-27 21:17:49,378 - polyssifier - INFO - Linear SVM                 3: Train 0.69/Test 0.21, 1168.55 sec
# 2022-11-27 21:18:01,924 - polyssifier - INFO - Training Linear SVM 4
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# 2022-11-27 21:38:29,033 - polyssifier - INFO - Linear SVM                 4: Train 0.71/Test 0.22, 1227.11 sec
# 2022-11-27 21:38:34,852 - polyssifier - INFO - Training Decision Tree 0
# 2022-11-27 21:38:38,707 - polyssifier - INFO - Decision Tree              0: Train 0.99/Test 0.20, 3.85 sec
# 2022-11-27 21:38:45,760 - polyssifier - INFO - Training Decision Tree 1
# 2022-11-27 21:38:51,790 - polyssifier - INFO - Decision Tree              1: Train 0.99/Test 0.25, 6.03 sec
# 2022-11-27 21:39:00,949 - polyssifier - INFO - Training Decision Tree 2
# 2022-11-27 21:39:07,777 - polyssifier - INFO - Decision Tree              2: Train 0.99/Test 0.21, 6.83 sec
# 2022-11-27 21:39:20,210 - polyssifier - INFO - Training Decision Tree 3
# 2022-11-27 21:39:26,262 - polyssifier - INFO - Decision Tree              3: Train 0.99/Test 0.20, 6.05 sec
# 2022-11-27 21:39:35,466 - polyssifier - INFO - Training Decision Tree 4
# 2022-11-27 21:39:41,864 - polyssifier - INFO - Decision Tree              4: Train 0.99/Test 0.25, 6.40 sec
# 2022-11-27 21:39:50,771 - polyssifier - INFO - Training Random Forest 0
# 2022-11-27 21:40:08,802 - polyssifier - INFO - Random Forest              0: Train 0.99/Test 0.24, 18.03 sec
# 2022-11-27 21:40:18,897 - polyssifier - INFO - Training Random Forest 1
# 2022-11-27 21:40:37,067 - polyssifier - INFO - Random Forest              1: Train 0.99/Test 0.24, 18.17 sec
# 2022-11-27 21:40:46,850 - polyssifier - INFO - Training Random Forest 2
# 2022-11-27 21:41:04,290 - polyssifier - INFO - Random Forest              2: Train 0.96/Test 0.26, 17.44 sec
# 2022-11-27 21:41:14,646 - polyssifier - INFO - Training Random Forest 3
# 2022-11-27 21:41:32,270 - polyssifier - INFO - Random Forest              3: Train 0.99/Test 0.25, 17.62 sec
# 2022-11-27 21:41:48,455 - polyssifier - INFO - Training Random Forest 4
# 2022-11-27 21:42:05,773 - polyssifier - INFO - Random Forest              4: Train 0.97/Test 0.25, 17.32 sec
# 2022-11-27 21:42:16,338 - polyssifier - INFO - Training Logistic Regression 0
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# 2022-11-27 21:42:49,141 - polyssifier - INFO - Logistic Regression        0: Train 0.72/Test 0.24, 32.80 sec
# 2022-11-27 21:43:06,782 - polyssifier - INFO - Training Logistic Regression 1
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# 2022-11-27 21:43:29,207 - polyssifier - INFO - Logistic Regression        1: Train 0.72/Test 0.28, 22.42 sec
# 2022-11-27 21:43:43,591 - polyssifier - INFO - Training Logistic Regression 2
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# 2022-11-27 21:44:05,668 - polyssifier - INFO - Logistic Regression        2: Train 0.72/Test 0.27, 22.08 sec
# 2022-11-27 21:44:22,265 - polyssifier - INFO - Training Logistic Regression 3
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# 2022-11-27 21:44:44,376 - polyssifier - INFO - Logistic Regression        3: Train 0.72/Test 0.23, 22.11 sec
# 2022-11-27 21:45:01,400 - polyssifier - INFO - Training Logistic Regression 4
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# 2022-11-27 21:45:23,311 - polyssifier - INFO - Logistic Regression        4: Train 0.73/Test 0.27, 21.91 sec
# 2022-11-27 21:45:38,835 - polyssifier - INFO - Training Naive Bayes 0
# 2022-11-27 21:45:51,353 - polyssifier - INFO - Naive Bayes                0: Train 0.37/Test 0.14, 12.52 sec
# 2022-11-27 21:46:06,670 - polyssifier - INFO - Training Naive Bayes 1
# 2022-11-27 21:46:17,864 - polyssifier - INFO - Naive Bayes                1: Train 0.37/Test 0.15, 11.19 sec
# 2022-11-27 21:46:33,186 - polyssifier - INFO - Training Naive Bayes 2
# 2022-11-27 21:46:42,605 - polyssifier - INFO - Naive Bayes                2: Train 0.38/Test 0.13, 9.42 sec
# 2022-11-27 21:46:56,381 - polyssifier - INFO - Training Naive Bayes 3
# 2022-11-27 21:47:06,075 - polyssifier - INFO - Naive Bayes                3: Train 0.37/Test 0.13, 9.69 sec
# 2022-11-27 21:47:20,078 - polyssifier - INFO - Training Naive Bayes 4
# 2022-11-27 21:47:28,913 - polyssifier - INFO - Naive Bayes                4: Train 0.37/Test 0.13, 8.83 sec
#                                  mean       std       min       max
# Multilayer Perceptron train  0.988958  0.001975  0.985979  0.991296
#                       test   0.242681  0.018005  0.221758  0.269490
# Nearest Neighbors     train  0.991733  0.000690  0.990700  0.992344
#                       test   0.225788  0.019161  0.202958  0.244199
# SVM                   train  0.455344  0.023698  0.427204  0.488406
#                       test   0.140724  0.021614  0.105461  0.161493
# Linear SVM            train  0.683238  0.021495  0.647880  0.705480
#                       test   0.228925  0.019560  0.210917  0.258631
# Decision Tree         train  0.992364  0.000668  0.991571  0.993040
#                       test   0.222732  0.026196  0.197805  0.254549
# Random Forest         train  0.979415  0.013788  0.962897  0.990082
#                       test   0.247711  0.009113  0.239503  0.261740
# Logistic Regression   train  0.721784  0.007289  0.715809  0.734390
#                       test   0.256884  0.018946  0.230075  0.275125
# Naive Bayes           train  0.372589  0.005422  0.366466  0.381105
#                       test   0.137434  0.007802  0.131957  0.150012
# Voting                train  0.980973  0.003893  0.974692  0.985086
#                       test   0.249347  0.027084  0.216706  0.273928
# 2022-11-27 21:49:19,876 - Report - INFO - Plotting Linear SVM coefs to temp_Linear SVM_feature_ranking.png
# Linear SVM
# 2022-11-27 21:49:20,191 - Report - INFO - Plotting Decision Tree coefs to temp_Decision Tree_feature_ranking.png
# Decision Tree
# 2022-11-27 21:49:20,520 - Report - INFO - Plotting Random Forest coefs to temp_Random Forest_feature_ranking.png
# Random Forest
# 2022-11-27 21:49:20,929 - Report - INFO - Plotting Logistic Regression coefs to temp_Logistic Regression_feature_ranking.png
# Logistic Regression

# %% [markdown]
# # Regression problem

# %%
from polyssifier import polyr
# Load data
data, labels = load_dataset("all", "regression")
# Run analysis
report = polyr(data, labels, n_folds=5)
# Plot results
report.plot_scores()
report.plot_features(ntop=10)
# Out:
# 2022-11-27 21:49:31,034 - polyssifier - INFO - Building classifiers ...
# 2022-11-27 21:49:31,044 - polyssifier - INFO - Initialization, done.
# 2022-11-27 21:49:42,561 - polyssifier - INFO - Training Linear Regression 0
# 2022-11-27 21:49:53,701 - polyssifier - INFO - Linear Regression          0: Train 0.29/Test -8447880263380475477787410432.00, 11.14 sec
# 2022-11-27 21:50:02,071 - polyssifier - INFO - Training Linear Regression 1
# 2022-11-27 21:50:08,154 - polyssifier - INFO - Linear Regression          1: Train 0.42/Test -4998121540169147972937842688.00, 6.08 sec
# 2022-11-27 21:50:16,510 - polyssifier - INFO - Training Linear Regression 2
# 2022-11-27 21:50:22,438 - polyssifier - INFO - Linear Regression          2: Train 0.42/Test -888303409524059267655532544.00, 5.93 sec
# 2022-11-27 21:50:30,184 - polyssifier - INFO - Training Linear Regression 3
# 2022-11-27 21:50:36,715 - polyssifier - INFO - Linear Regression          3: Train 0.39/Test -9802170625541052526328020992.00, 6.53 sec
# 2022-11-27 21:50:45,393 - polyssifier - INFO - Training Linear Regression 4
# 2022-11-27 21:50:51,502 - polyssifier - INFO - Linear Regression          4: Train 0.36/Test -3674801961109224533583200256.00, 6.11 sec
# 2022-11-27 21:50:59,556 - polyssifier - INFO - Training Bayesian Ridge 0
# 2022-11-27 21:51:06,643 - polyssifier - INFO - Bayesian Ridge             0: Train 0.30/Test 0.11, 7.09 sec
# 2022-11-27 21:51:15,060 - polyssifier - INFO - Training Bayesian Ridge 1
# 2022-11-27 21:51:21,017 - polyssifier - INFO - Bayesian Ridge             1: Train 0.31/Test 0.06, 5.96 sec
# 2022-11-27 21:51:28,373 - polyssifier - INFO - Training Bayesian Ridge 2
# 2022-11-27 21:51:34,419 - polyssifier - INFO - Bayesian Ridge             2: Train 0.28/Test 0.10, 6.05 sec
# 2022-11-27 21:51:42,863 - polyssifier - INFO - Training Bayesian Ridge 3
# 2022-11-27 21:51:49,621 - polyssifier - INFO - Bayesian Ridge             3: Train 0.30/Test 0.07, 6.76 sec
# 2022-11-27 21:51:57,976 - polyssifier - INFO - Training Bayesian Ridge 4
# 2022-11-27 21:52:05,227 - polyssifier - INFO - Bayesian Ridge             4: Train 0.30/Test 0.08, 7.25 sec
# 2022-11-27 21:52:14,289 - polyssifier - INFO - Training PassiveAggressiveRegressor 0
# 2022-11-27 21:52:23,048 - polyssifier - INFO - PassiveAggressiveRegressor  0: Train -1.81/Test -6.28, 8.76 sec
# 2022-11-27 21:52:33,716 - polyssifier - INFO - Training PassiveAggressiveRegressor 1
# 2022-11-27 21:52:41,480 - polyssifier - INFO - PassiveAggressiveRegressor  1: Train -2.42/Test -4.22, 7.76 sec
# 2022-11-27 21:52:49,902 - polyssifier - INFO - Training PassiveAggressiveRegressor 2
# 2022-11-27 21:52:57,498 - polyssifier - INFO - PassiveAggressiveRegressor  2: Train -2.08/Test -3.51, 7.60 sec
# 2022-11-27 21:53:06,304 - polyssifier - INFO - Training PassiveAggressiveRegressor 3
# 2022-11-27 21:53:14,280 - polyssifier - INFO - PassiveAggressiveRegressor  3: Train -1.45/Test -2.93, 7.98 sec
# 2022-11-27 21:53:22,946 - polyssifier - INFO - Training PassiveAggressiveRegressor 4
# 2022-11-27 21:53:28,734 - polyssifier - INFO - PassiveAggressiveRegressor  4: Train -1.37/Test -3.13, 5.79 sec
# 2022-11-27 21:53:37,151 - polyssifier - INFO - Training GaussianProcessRegressor 0
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# 2022-11-27 22:06:47,985 - polyssifier - INFO - GaussianProcessRegressor   0: Train -0.00/Test -0.00, 790.84 sec
# 2022-11-27 22:06:55,609 - polyssifier - INFO - Training GaussianProcessRegressor 1
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# 2022-11-27 22:21:26,073 - polyssifier - INFO - GaussianProcessRegressor   1: Train -0.00/Test -0.00, 870.47 sec
# 2022-11-27 22:21:37,339 - polyssifier - INFO - Training GaussianProcessRegressor 2
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# 2022-11-27 22:38:42,520 - polyssifier - INFO - GaussianProcessRegressor   2: Train -0.00/Test -0.00, 1025.18 sec
# 2022-11-27 22:39:05,567 - polyssifier - INFO - Training GaussianProcessRegressor 3
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# 2022-11-27 22:53:56,302 - polyssifier - INFO - GaussianProcessRegressor   3: Train -0.00/Test -0.00, 890.74 sec
# 2022-11-27 22:54:07,817 - polyssifier - INFO - Training GaussianProcessRegressor 4
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# 2022-11-27 23:11:53,269 - polyssifier - INFO - GaussianProcessRegressor   4: Train -0.00/Test -0.01, 1065.45 sec
# 2022-11-27 23:12:01,796 - polyssifier - INFO - Training Ridge 0
# 2022-11-27 23:12:09,218 - polyssifier - INFO - Ridge                      0: Train 0.48/Test -9.94, 7.42 sec
# 2022-11-27 23:12:17,853 - polyssifier - INFO - Training Ridge 1
# 2022-11-27 23:12:25,521 - polyssifier - INFO - Ridge                      1: Train 0.49/Test -0.70, 7.67 sec
# 2022-11-27 23:12:34,551 - polyssifier - INFO - Training Ridge 2
# 2022-11-27 23:12:42,752 - polyssifier - INFO - Ridge                      2: Train 0.46/Test -0.63, 8.20 sec
# 2022-11-27 23:12:53,314 - polyssifier - INFO - Training Ridge 3
# 2022-11-27 23:13:03,730 - polyssifier - INFO - Ridge                      3: Train 0.47/Test -0.73, 10.42 sec
# 2022-11-27 23:13:12,864 - polyssifier - INFO - Training Ridge 4
# 2022-11-27 23:13:20,280 - polyssifier - INFO - Ridge                      4: Train 0.48/Test -0.47, 7.42 sec
# 2022-11-27 23:13:28,985 - polyssifier - INFO - Training Lasso 0
# 2022-11-27 23:13:36,074 - polyssifier - INFO - Lasso                      0: Train 0.00/Test -0.00, 7.09 sec
# 2022-11-27 23:13:45,148 - polyssifier - INFO - Training Lasso 1
# 2022-11-27 23:13:52,878 - polyssifier - INFO - Lasso                      1: Train 0.00/Test -0.00, 7.73 sec
# 2022-11-27 23:14:03,410 - polyssifier - INFO - Training Lasso 2
# 2022-11-27 23:14:11,438 - polyssifier - INFO - Lasso                      2: Train 0.00/Test -0.00, 8.03 sec
# 2022-11-27 23:14:24,243 - polyssifier - INFO - Training Lasso 3
# 2022-11-27 23:14:30,971 - polyssifier - INFO - Lasso                      3: Train 0.00/Test -0.00, 6.73 sec
# 2022-11-27 23:14:40,743 - polyssifier - INFO - Training Lasso 4
# 2022-11-27 23:14:49,862 - polyssifier - INFO - Lasso                      4: Train 0.00/Test -0.01, 9.12 sec
# 2022-11-27 23:14:57,477 - polyssifier - INFO - Training Lars 0
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_base.py:138: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lars())
#
# ...
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   FutureWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_base.py:138: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   FutureWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_base.py:138: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   FutureWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_base.py:138: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   FutureWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_base.py:138: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   FutureWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_base.py:138: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   FutureWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_base.py:138: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   FutureWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_base.py:138: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   FutureWarning,
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_base.py:138: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   FutureWarning,
# 2022-11-27 23:17:54,130 - polyssifier - INFO - LassoLars                  4: Train 0.00/Test -0.01, 11.60 sec
# 2022-11-27 23:18:03,879 - polyssifier - INFO - Training OrthogonalMatchingPursuit 0
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_base.py:138: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), OrthogonalMatchingPursuit())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   FutureWarning,
# 2022-11-27 23:18:10,110 - polyssifier - INFO - OrthogonalMatchingPursuit  0: Train 0.26/Test -0.02, 6.23 sec
# 2022-11-27 23:18:24,047 - polyssifier - INFO - Training OrthogonalMatchingPursuit 1
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_base.py:138: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), OrthogonalMatchingPursuit())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   FutureWarning,
# 2022-11-27 23:18:35,576 - polyssifier - INFO - OrthogonalMatchingPursuit  1: Train 0.27/Test -0.06, 11.53 sec
# 2022-11-27 23:18:51,315 - polyssifier - INFO - Training OrthogonalMatchingPursuit 2
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_base.py:138: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), OrthogonalMatchingPursuit())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   FutureWarning,
# 2022-11-27 23:18:59,664 - polyssifier - INFO - OrthogonalMatchingPursuit  2: Train 0.26/Test -0.04, 8.35 sec
# 2022-11-27 23:19:14,704 - polyssifier - INFO - Training OrthogonalMatchingPursuit 3
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_base.py:138: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), OrthogonalMatchingPursuit())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   FutureWarning,
# 2022-11-27 23:19:28,310 - polyssifier - INFO - OrthogonalMatchingPursuit  3: Train 0.25/Test -0.08, 13.61 sec
# 2022-11-27 23:19:50,346 - polyssifier - INFO - Training OrthogonalMatchingPursuit 4
# /Users/pavelpopov/.pyenv/versions/3.7.12/lib/python3.7/site-packages/sklearn/linear_model/_base.py:138: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), OrthogonalMatchingPursuit())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   FutureWarning,
# 2022-11-27 23:20:03,551 - polyssifier - INFO - OrthogonalMatchingPursuit  4: Train 0.26/Test 0.01, 13.20 sec
# 2022-11-27 23:20:24,309 - polyssifier - INFO - Training ElasticNet 0
# 2022-11-27 23:20:44,198 - polyssifier - INFO - ElasticNet                 0: Train 0.00/Test -0.00, 19.89 sec
# 2022-11-27 23:21:06,779 - polyssifier - INFO - Training ElasticNet 1
# 2022-11-27 23:21:27,689 - polyssifier - INFO - ElasticNet                 1: Train 0.00/Test 0.00, 20.91 sec
# 2022-11-27 23:21:47,695 - polyssifier - INFO - Training ElasticNet 2
# 2022-11-27 23:22:07,143 - polyssifier - INFO - ElasticNet                 2: Train 0.00/Test -0.00, 19.45 sec
# 2022-11-27 23:22:26,655 - polyssifier - INFO - Training ElasticNet 3
# 2022-11-27 23:22:40,588 - polyssifier - INFO - ElasticNet                 3: Train 0.01/Test -0.00, 13.93 sec
# 2022-11-27 23:22:54,606 - polyssifier - INFO - Training ElasticNet 4
# 2022-11-27 23:23:08,101 - polyssifier - INFO - ElasticNet                 4: Train 0.00/Test -0.01, 13.49 sec
#                                           mean           std           min  \
# Linear Regression          train  3.748572e-01  5.475618e-02  2.893803e-01
#                            test  -5.562256e+27  3.606600e+27 -9.802171e+27
# Bayesian Ridge             train  2.981585e-01  1.071569e-02  2.840921e-01
#                            test   8.596620e-02  2.193101e-02  6.010265e-02
# PassiveAggressiveRegressor train -1.825949e+00  4.382517e-01 -2.420161e+00
#                            test  -4.012920e+00  1.358337e+00 -6.277495e+00
# GaussianProcessRegressor   train -1.979779e-06  2.743976e-08 -1.998182e-06
#                            test  -2.553928e-03  3.314874e-03 -7.563445e-03
# Ridge                      train  4.752089e-01  1.022345e-02  4.629822e-01
#                            test  -2.494341e+00  4.161118e+00 -9.935777e+00
# Lasso                      train  0.000000e+00  0.000000e+00  0.000000e+00
#                            test  -2.553150e-03  3.405758e-03 -7.838156e-03
# Lars                       train  3.318029e-01  6.869526e-03  3.209604e-01
#                            test   4.062810e-02  3.427186e-02 -6.427962e-03
# LassoLars                  train  0.000000e+00  0.000000e+00  0.000000e+00
#                            test  -2.553150e-03  3.405758e-03 -7.838156e-03
# OrthogonalMatchingPursuit  train  2.574275e-01  5.791497e-03  2.499639e-01
#                            test  -3.948504e-02  3.183363e-02 -7.668840e-02
# ElasticNet                 train  1.728953e-03  2.482107e-03  1.365701e-04
#                            test  -1.720103e-03  3.409358e-03 -7.540172e-03
# Median                     train  2.571547e-01  1.074501e-02  2.461200e-01
#                            test   7.347346e-02  1.634469e-02  5.713836e-02
#
#                                            max
# Linear Regression          train  4.240249e-01
#                            test  -8.883034e+26
# Bayesian Ridge             train  3.142060e-01
#                            test   1.147685e-01
# PassiveAggressiveRegressor train -1.370076e+00
#                            test  -2.929035e+00
# GaussianProcessRegressor   train -1.931717e-06
#                            test  -1.108348e-04
# Ridge                      train  4.903095e-01
#                            test  -4.715395e-01
# Lasso                      train  0.000000e+00
#                            test  -1.450598e-04
# Lars                       train  3.395106e-01
#                            test   8.315842e-02
# LassoLars                  train  0.000000e+00
#                            test  -1.450598e-04
# OrthogonalMatchingPursuit  train  2.660514e-01
#                            test   5.272434e-03
# ElasticNet                 train  5.985159e-03
#                            test   9.004160e-04
# Median                     train  2.697013e-01
#                            test   9.768160e-02
# 2022-11-27 23:24:17,828 - Report - INFO - Plotting Linear Regression coefs to temp_Linear Regression_feature_ranking.png
# Linear Regression
# 2022-11-27 23:24:18,122 - Report - INFO - Plotting Bayesian Ridge coefs to temp_Bayesian Ridge_feature_ranking.png
# Bayesian Ridge
# 2022-11-27 23:24:18,415 - Report - INFO - Plotting PassiveAggressiveRegressor coefs to temp_PassiveAggressiveRegressor_feature_ranking.png
# PassiveAggressiveRegressor
# 2022-11-27 23:24:18,741 - Report - INFO - Plotting Ridge coefs to temp_Ridge_feature_ranking.png
# Ridge
# 2022-11-27 23:24:19,028 - Report - INFO - Plotting Lasso coefs to temp_Lasso_feature_ranking.png
# Lasso
# 2022-11-27 23:24:19,308 - Report - INFO - Plotting Lars coefs to temp_Lars_feature_ranking.png
# Lars
# 2022-11-27 23:24:19,661 - Report - INFO - Plotting LassoLars coefs to temp_LassoLars_feature_ranking.png
# LassoLars
# 2022-11-27 23:24:20,268 - Report - INFO - Plotting OrthogonalMatchingPursuit coefs to temp_OrthogonalMatchingPursuit_feature_ranking.png
# OrthogonalMatchingPursuit
# 2022-11-27 23:24:20,564 - Report - INFO - Plotting ElasticNet coefs to temp_ElasticNet_feature_ranking.png
# ElasticNet
